# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/NUS_GAIP_GRP9/HPE Project/Datasets/Merged_food.csv')

# %%
# Extract only the time series which have data of all 145 weeks
col_name=df.columns
updated_df=pd.DataFrame(columns=col_name)

for x in df['meal_id'].unique():
  #print('meal_id={}'.format(x))
  for y in df['center_id'].unique():
    #print('center_id={}'.format(y))
    j=0
    temp=df[df['center_id']==y]
    temp=temp[temp['meal_id']==x]
    if temp.empty:
      continue
    if len(temp)!=145:
     #print("skipped{} {}".format(x,y))
      continue
    updated_df=pd.concat([updated_df,temp])

# %%
updated_df=pd.read_csv(('/content/drive/MyDrive/NUS_GAIP_GRP9/HPE Project/Datasets/Extracted_food.csv'))
updated_df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)

# %%
def calc_mean(col):
  return col.mean()

# %%
#Extracting a portion of the dataset
data_new = pd.DataFrame(updated_df.groupby(['center_id','week']).agg({'num_orders':sum,'base_price':calc_mean}))
data_new = data_new.reset_index()
temp = data_new

# %%
#Dummy encoding the categorical column
dummy=pd.get_dummies(data_new['center_id'], prefix=['center_id'])

# %%
#Merging the newly created dummy columns with the original dataset
data_new = pd.merge(data_new,dummy,on=data_new.index)
data_new.drop(['key_0','center_id'],axis=1,inplace=True)

# %%
#Splitting the dataset into train, validation and test sets
train = data_new[data_new['week'].isin(range(1,100))]
val = data_new[data_new['week'].isin(range(100,130))]
test = data_new[data_new['week'].isin(range(130,146))]
print(len(train), len(val), len(test))
# Out:
# 7524 2280 1216

# %%
'''#Splitting the dataset into X_train, y_train and so on
X_train = train.drop('num_orders',axis=1)
y_train = train['num_orders']

X_val = val.drop('num_orders',axis=1)
y_val = val['num_orders']

X_test = test.drop('num_orders',axis=1)
y_test = test['num_orders']

X_train=np.array(X_train)
X_val=np.array(X_val)
X_test=np.array(X_test)'''

# %%
#Performing Robust scaling on the num_orders column
from sklearn.preprocessing import RobustScaler
scaler= RobustScaler()
scaler.fit(np.array(train[['num_orders']]).reshape(-1,1))
train['num_orders'] = scaler.transform(np.array(train[['num_orders']]).reshape(-1,1))
val['num_orders'] = scaler.transform(np.array(val[['num_orders']]).reshape(-1,1))
test['num_orders'] = scaler.transform(np.array(test[['num_orders']]).reshape(-1,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Performing Robust scaling on the base_price column
scaler.fit(np.array(train[['base_price']]).reshape(-1,1))
train['base_price'] = scaler.transform(np.array(train[['base_price']]).reshape(-1,1))
val['base_price'] = scaler.transform(np.array(val[['base_price']]).reshape(-1,1))
test['base_price'] = scaler.transform(np.array(test[['base_price']]).reshape(-1,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Create dataset function to convert the train test and validation sets into numpy arrays
def create_dataset(X, y, time_steps=1, weeks=100):
    Xs, ys = [], []
    total=len(X)//weeks # floor division
    for j in range(total):
      
      for i in range(weeks - time_steps):
        i=i+j*weeks
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
#Invoking the create dataset function
x_train,y_train=create_dataset(train.drop('num_orders',axis=1), train['num_orders'], time_steps=2, weeks=100)
x_val, y_val=create_dataset(val.drop('num_orders',axis=1), val['num_orders'], time_steps=2, weeks=30)
x_test, y_test=create_dataset(test.drop('num_orders',axis=1), test['num_orders'], time_steps=2, weeks=16)

# %%
y_val
# Out:
# array([ 2.58648526,  1.46557823,  1.71664399, ..., -0.56290249,
#        -0.45043084, -0.44517007])

# %%
#Successful Architecture 1_GRU 
from tensorflow import keras
import tensorflow as tf
from keras.layers import BatchNormalization
from tensorflow.keras import regularizers

model = keras.Sequential()
model.add(
    keras.layers.GRU(
      units=32, 
      input_shape=(x_train.shape[1], x_train.shape[2]),
      activation = 'sigmoid',
      return_sequences = True
    )
  )

'''model.add(keras.layers.Dropout(rate=0.5))
model.add(BatchNormalization())

model.add(
    keras.layers.GRU(
      units=32, 
      input_shape=(x_train.shape[1], x_train.shape[2]),
      activation = 'tanh',
      return_sequences = True
    )
  )'''

model.add(keras.layers.Dropout(rate=0.3))
model.add(BatchNormalization())
model.add(
    keras.layers.GRU(
      units=16, 
      input_shape=(x_train.shape[1], x_train.shape[2]),
      activation = 'tanh',
      return_sequences = False
    )
  )

model.add(keras.layers.Dropout(rate=0.3))
model.add(BatchNormalization())

model.add(keras.layers.Dense(units=16))
model.add(keras.layers.Dropout(0.3))

model.add(keras.layers.Dense(16, kernel_regularizer=regularizers.l2(0.02)))
model.add(keras.layers.Dropout(0.3))

model.add(keras.layers.Dense(units=1))

model.compile(loss='mse', optimizer=keras.optimizers.Adam(learning_rate=0.001))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_4 (GRU)                  (None, 2, 32)             10752
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2, 32)             0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 2, 32)             128
# _________________________________________________________________
# gru_5 (GRU)                  (None, 16)                2400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16)                0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16)                64
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 13,905
# Trainable params: 13,809
# Non-trainable params: 96
# _________________________________________________________________

# %%
'''earlystop=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    mode="min",
    restore_best_weights=True,
)'''

history = model.fit(x=x_train,y=y_train,
          validation_data = (x_val,y_val),
          batch_size=128, epochs=100, callbacks=earlystop)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 4s 15ms/step - loss: 4.1389 - val_loss: 1.0542
# Epoch 2/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.9811 - val_loss: 1.0346
# Epoch 3/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5935 - val_loss: 1.0182
# Epoch 4/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.3854 - val_loss: 1.0007
# Epoch 5/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2633 - val_loss: 0.9846
# Epoch 6/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2059 - val_loss: 0.9697
# Epoch 7/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1370 - val_loss: 0.9556
# Epoch 8/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1041 - val_loss: 0.9422
# Epoch 9/100
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0712 - val_loss: 0.9289
# Epoch 10/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0195 - val_loss: 0.9166
# Epoch 11/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0000 - val_loss: 0.9045
# Epoch 12/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9806 - val_loss: 0.8921
# Epoch 13/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9589 - val_loss: 0.8778
# Epoch 14/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9348 - val_loss: 0.8641
# Epoch 15/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9069 - val_loss: 0.8433
# Epoch 16/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.8750 - val_loss: 0.8223
# Epoch 17/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.8373 - val_loss: 0.8011
# Epoch 18/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7960 - val_loss: 0.7542
# Epoch 19/100
# 58/58 [==============================] - 0s 8ms/step - loss: 0.7369 - val_loss: 0.6766
# Epoch 20/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6847 - val_loss: 0.5511
# Epoch 21/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6207 - val_loss: 0.5340
# Epoch 22/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.5852 - val_loss: 0.5330
# Epoch 23/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5380 - val_loss: 0.4348
# Epoch 24/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4955 - val_loss: 0.3604
# Epoch 25/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4641 - val_loss: 0.3437
# Epoch 26/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4357 - val_loss: 0.3149
# Epoch 27/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4324 - val_loss: 0.3027
# Epoch 28/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4123 - val_loss: 0.2862
# Epoch 29/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3948 - val_loss: 0.3478
# Epoch 30/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3977 - val_loss: 0.2720
# Epoch 31/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3735 - val_loss: 0.2270
# Epoch 32/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3608 - val_loss: 0.2176
# Epoch 33/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3484 - val_loss: 0.3020
# Epoch 34/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3397 - val_loss: 0.2107
# Epoch 35/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3275 - val_loss: 0.2492
# Epoch 36/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3189 - val_loss: 0.1298
# Epoch 37/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3130 - val_loss: 0.2456
# Epoch 38/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3110 - val_loss: 0.1423
# Epoch 39/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3027 - val_loss: 0.1748
# Epoch 40/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3000 - val_loss: 0.1604
# Epoch 41/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2987 - val_loss: 0.1739
# Epoch 42/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2980 - val_loss: 0.1853
# Epoch 43/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2856 - val_loss: 0.1391
# Epoch 44/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2838 - val_loss: 0.1536
# Epoch 45/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2878 - val_loss: 0.1668
# Epoch 46/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2742 - val_loss: 0.1877
# Epoch 47/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2832 - val_loss: 0.1311
# Epoch 48/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2716 - val_loss: 0.1470
# Epoch 49/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2691 - val_loss: 0.1310
# Epoch 50/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2624 - val_loss: 0.1400
# Epoch 51/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2605 - val_loss: 0.1029
# Epoch 52/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2635 - val_loss: 0.1417
# Epoch 53/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2563 - val_loss: 0.1434
# Epoch 54/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2534 - val_loss: 0.1822
# Epoch 55/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2534 - val_loss: 0.1477
# Epoch 56/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2524 - val_loss: 0.1538
# Epoch 57/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2477 - val_loss: 0.1188
# Epoch 58/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2575 - val_loss: 0.1659
# Epoch 59/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2395 - val_loss: 0.0948
# Epoch 60/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2452 - val_loss: 0.0924
# Epoch 61/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2413 - val_loss: 0.1316
# Epoch 62/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2386 - val_loss: 0.1260
# Epoch 63/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2463 - val_loss: 0.1183
# Epoch 64/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2362 - val_loss: 0.0714
# Epoch 65/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2484 - val_loss: 0.1146
# Epoch 66/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2426 - val_loss: 0.1122
# Epoch 67/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2444 - val_loss: 0.1784
# Epoch 68/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2365 - val_loss: 0.1597
# Epoch 69/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2352 - val_loss: 0.1527
# Epoch 70/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2387 - val_loss: 0.1298
# Epoch 71/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2297 - val_loss: 0.1122
# Epoch 72/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2313 - val_loss: 0.2207
# Epoch 73/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2331 - val_loss: 0.1491
# Epoch 74/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2349 - val_loss: 0.1370
# Epoch 75/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2437 - val_loss: 0.1296
# Epoch 76/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2252 - val_loss: 0.1106
# Epoch 77/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2196 - val_loss: 0.1006
# Epoch 78/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2368 - val_loss: 0.1083
# Epoch 79/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2279 - val_loss: 0.1130
# Epoch 80/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2317 - val_loss: 0.0951
# Epoch 81/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2210 - val_loss: 0.1471
# Epoch 82/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2262 - val_loss: 0.1254
# Epoch 83/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2240 - val_loss: 0.1362
# Epoch 84/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2303 - val_loss: 0.1875
# Epoch 85/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2157 - val_loss: 0.1126
# Epoch 86/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2246 - val_loss: 0.1258
# Epoch 87/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2139 - val_loss: 0.0857
# Epoch 88/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2195 - val_loss: 0.1010
# Epoch 89/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2308 - val_loss: 0.0900
# Epoch 90/100
# 58/58 [==============================] - 0s 8ms/step - loss: 0.2251 - val_loss: 0.0983
# Epoch 91/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2225 - val_loss: 0.1299
# Epoch 92/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2155 - val_loss: 0.1427
# Epoch 93/100
# 58/58 [==============================] - 0s 8ms/step - loss: 0.2227 - val_loss: 0.1583
# Epoch 94/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2191 - val_loss: 0.0874
# Epoch 95/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2218 - val_loss: 0.1229
# Epoch 96/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2175 - val_loss: 0.1299
# Epoch 97/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2195 - val_loss: 0.1169
# Epoch 98/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2142 - val_loss: 0.1223
# Epoch 99/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2220 - val_loss: 0.1039
# Epoch 100/100
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2181 - val_loss: 0.1146

# %%
earlystop=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    mode="min",
    restore_best_weights=True,
)

history = model.fit(x=x_train,y=y_train,
          validation_data = (x_val,y_val),
          batch_size=128, epochs=100, callbacks=earlystop)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 4s 16ms/step - loss: 2.0488 - val_loss: 1.0266
# Epoch 2/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.4335 - val_loss: 0.9983
# Epoch 3/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2522 - val_loss: 0.9738
# Epoch 4/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1454 - val_loss: 0.9516
# Epoch 5/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0933 - val_loss: 0.9299
# Epoch 6/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0414 - val_loss: 0.9099
# Epoch 7/100
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0046 - val_loss: 0.8934
# Epoch 8/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9841 - val_loss: 0.8699
# Epoch 9/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9343 - val_loss: 0.8371
# Epoch 10/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8823 - val_loss: 0.7876
# Epoch 11/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8175 - val_loss: 0.7369
# Epoch 12/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7264 - val_loss: 0.6826
# Epoch 13/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6435 - val_loss: 0.6653
# Epoch 14/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5534 - val_loss: 0.7057
# Epoch 15/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5164 - val_loss: 0.6539
# Epoch 16/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.4722 - val_loss: 0.4049
# Epoch 17/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4507 - val_loss: 0.3130
# Epoch 18/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.4273 - val_loss: 0.2417
# Epoch 19/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.3906 - val_loss: 0.4665
# Epoch 20/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3746 - val_loss: 0.3258
# Epoch 21/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.3661 - val_loss: 0.2477
# Epoch 22/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3541 - val_loss: 0.2918
# Epoch 23/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.3325 - val_loss: 0.2681
# Epoch 24/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3325 - val_loss: 0.2987
# Epoch 25/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3200 - val_loss: 0.2780
# Epoch 26/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3138 - val_loss: 0.2070
# Epoch 27/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3026 - val_loss: 0.1539
# Epoch 28/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.3102 - val_loss: 0.1992
# Epoch 29/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2888 - val_loss: 0.2278
# Epoch 30/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2832 - val_loss: 0.2408
# Epoch 31/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2837 - val_loss: 0.1823
# Epoch 32/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2725 - val_loss: 0.1681
# Epoch 33/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2863 - val_loss: 0.1556
# Epoch 34/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2686 - val_loss: 0.1449
# Epoch 35/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2630 - val_loss: 0.1952
# Epoch 36/100
# 58/58 [==============================] - 0s 5ms/step - loss: 0.2632 - val_loss: 0.1914
# Epoch 37/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2580 - val_loss: 0.3537
# Epoch 38/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2493 - val_loss: 0.1460
# Epoch 39/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2549 - val_loss: 0.2063
# Epoch 40/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2577 - val_loss: 0.1830
# Epoch 41/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2579 - val_loss: 0.2909
# Epoch 42/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2506 - val_loss: 0.2200
# Epoch 43/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2566 - val_loss: 0.2484
# Epoch 44/100
# 58/58 [==============================] - 0s 6ms/step - loss: 0.2424 - val_loss: 0.3082

# %%
plt.plot(history.history['val_loss'])
plt.plot(history.history['loss'])
plt.legend(['validation','train'])
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
y_pred = model.predict(x_val)
y_pred
# Out:
# array([[ 1.7345864 ],
#        [ 1.7400987 ],
#        [ 1.7343434 ],
#        ...,
#        [-0.49974948],
#        [-0.49270606],
#        [-0.48908323]], dtype=float32)

# %%
plt.plot(y_val)

# %%
plt.plot(y_pred)

# %%
y_pred_test = model.predict(x_test)
y_pred)test
# Out:
# array([[ 1.8917711 ],
#        [ 1.8372604 ],
#        [ 1.8783923 ],
#        ...,
#        [-0.4957773 ],
#        [-0.50029427],
#        [-0.5140929 ]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_test)
# Out:
# 0.8008594416924686

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred_test)
# Out:
# 0.14250387000808803

# %%
plt.plot(y_pred_test)

# %%
plt.plot(y_test)

# %%
y_pred_test = y_pred_test.flatten()
y_pred.shape
# Out:
# (1064,)

# %%
plt.scatter(range(len(y_test)),y_test-y_pred_test)

# %%
model.save_weights('/content/drive/MyDrive/GRUSuccess1.h5')
